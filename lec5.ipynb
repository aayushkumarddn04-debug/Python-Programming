# %%
l = ["aayush kumar", "kumar aayush"]

# %%
for item in l:
    if item.split()[1] == "kumar":
        return print("second name found")
# Out:
#   Cell In[2], line 3
#     return print("second name found")
#     ^
# SyntaxError: 'return' outside function
