# %%
a = {20,30,40}

# %%
type(a)
# Out:
# set

# %%
for item in a:
    print(item)
# Out:
# 40
# 20
# 30

# %% [markdown]
# python is dynamically typed language
# is a interapetr
# object oriented

# %%
a = {20,30,40}

# %%
a
# Out:
# {20, 30, 40}

# %%
b = {30,50}

# %%
a.intersection(b)
# Out:
# {30}

# %%
type(a.union(b))
# Out:
# set

# %%
a.union(b)
# Out:
# {20, 30, 40, 50}

# %%
l = ["vibhu",209,False,[12,3]]

# %% [markdown]
# you can only loop over a sequence

# %%
for item in (l):
    print (item)
# Out:
# vibhu
# 209
# False
# [12, 3]

# %% [markdown]
# any object in sequence is called an iterator

# %%
names = ["A", "B", "C"]
for idx, val in enumerate(names):
    print(idx, val)
# Out:
# 0 A
# 1 B
# 2 C

# %%
for idx, val in enumerate(names, start=1):
    print(idx, val)
# Out:
# 1 A
# 2 B
# 3 C
